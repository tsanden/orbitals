# %%
import orbitals as orb

# %%
orb.plot_orbital(n=[1,2,3,3,3], l=[0,1,0,1,2], m=[0,1,0,0,0], sample=200, radius=30, scatter=True, axis=False, cmap='gray', rows=2, cols=3)

# %%
orb.plot_orbital(n=[1,2,3,3,3], l=[0,1,0,1,2], m=[0,1,0,0,0], sample=100, radius=30, scatter=False, axis=False, cmap='gray', rows=2, cols=3)
